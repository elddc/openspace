# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)

# %%
import requests

# %%
url = 'https://goboardapi.azurewebsites.net/api/FacilityCount/GetCountsByAccount?AccountAPIKey=38902ca4-0d3b-409e-903e-615e5e530612'

requests.get(url).json()
# Out:
# [{'LocationId': 2900,
#   'TotalCapacity': 79,
#   'LocationName': 'Entrance Level Fitness Area ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T15:02:50.707',
#   'LastCount': 11,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2928,
#   'TotalCapacity': 200,
#   'LocationName': 'Ice Rink',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2018-01-03T14:30:56.933',
#   'LastCount': 22,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 578,
#   'FacilityName': 'Ice Arena',
#   'IsClosed': False},
#  {'LocationId': 2926,
#   'TotalCapacity': 200,
#   'LocationName': 'Lobby Area',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T20:11:17.307',
#   'LastCount': 1,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': False},
#  {'LocationId': 2929,
#   'TotalCapacity': 100,
#   'LocationName': 'Ice Arena Lobby',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2018-01-03T14:30:57.09',
#   'LastCount': 8,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 578,
#   'FacilityName': 'Ice Arena',
#   'IsClosed': False},
#  {'LocationId': 2871,
#   'TotalCapacity': 250,
#   'LocationName': 'Upper Level',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T15:02:51.36',
#   'LastCount': 24,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2910,
#   'TotalCapacity': 1284,
#   'LocationName': 'Main Gym ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T20:11:17.9',
#   'LastCount': 33,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': False},
#  {'LocationId': 2874,
#   'TotalCapacity': 200,
#   'LocationName': 'Lower Level',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T15:04:24.053',
#   'LastCount': 49,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2930,
#   'TotalCapacity': 60,
#   'LocationName': 'Stick and Puck',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2018-01-03T15:09:44.353',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 578,
#   'FacilityName': 'Ice Arena',
#   'IsClosed': False},
#  {'LocationId': 2879,
#   'TotalCapacity': 82,
#   'LocationName': 'Indoor Pool',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T08:34:24.683',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': True},
#  {'LocationId': 6154,
#   'TotalCapacity': 159,
#   'LocationName': 'Strength and Conditioning  ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T15:04:24.787',
#   'LastCount': 84,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2931,
#   'TotalCapacity': 15,
#   'LocationName': 'Hot Tub',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T07:34:57.733',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': True},
#  {'LocationId': 2877,
#   'TotalCapacity': 963,
#   'LocationName': 'Indoor Pool',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T12:01:43.5',
#   'LastCount': 10,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2916,
#   'TotalCapacity': 10,
#   'LocationName': 'Raquetball Courts',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T20:11:18.65',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': False},
#  {'LocationId': 2917,
#   'TotalCapacity': 177,
#   'LocationName': 'MP 1',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T13:02:06.607',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': False},
#  {'LocationId': 2878,
#   'TotalCapacity': 1106,
#   'LocationName': 'Outdoor Pool',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T15:23:36.16',
#   'LastCount': 28,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2909,
#   'TotalCapacity': 15,
#   'LocationName': 'Sauna',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T15:24:30.98',
#   'LastCount': 3,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2918,
#   'TotalCapacity': 177,
#   'LocationName': 'MP 2',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T13:02:07.23',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': False},
#  {'LocationId': 2919,
#   'TotalCapacity': 4,
#   'LocationName': 'Squash Court',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T13:02:09.623',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': False},
#  {'LocationId': 2898,
#   'TotalCapacity': 21,
#   'LocationName': 'Combat Room',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T06:40:11.437',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2875,
#   'TotalCapacity': 100,
#   'LocationName': 'MAC Gym',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T13:02:08.97',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': False},
#  {'LocationId': 2889,
#   'TotalCapacity': 317,
#   'LocationName': 'Gym 1 ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T14:12:37.03',
#   'LastCount': 19,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2922,
#   'TotalCapacity': 500,
#   'LocationName': 'Upper Level ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T20:11:19.197',
#   'LastCount': 33,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 579,
#   'FacilityName': 'CRCE',
#   'IsClosed': False},
#  {'LocationId': 2890,
#   'TotalCapacity': 131,
#   'LocationName': 'Gym 2 ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T15:01:27.217',
#   'LastCount': 8,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2891,
#   'TotalCapacity': 132,
#   'LocationName': 'Gym 3 ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T15:01:27.873',
#   'LastCount': 32,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2906,
#   'TotalCapacity': 8,
#   'LocationName': 'Rock Wall',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-19T07:09:17.223',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': True},
#  {'LocationId': 2901,
#   'TotalCapacity': 250,
#   'LocationName': 'Raquetball Courts',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T14:02:47.353',
#   'LastCount': 10,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2902,
#   'TotalCapacity': 4,
#   'LocationName': 'Squash Courts',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T14:02:47.88',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2892,
#   'TotalCapacity': 196,
#   'LocationName': 'MP Room 1',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T09:12:24.107',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2893,
#   'TotalCapacity': 196,
#   'LocationName': 'MP Room 2',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T09:12:24.75',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2894,
#   'TotalCapacity': 30,
#   'LocationName': 'MP Room 3',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T09:12:25.387',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2895,
#   'TotalCapacity': 75,
#   'LocationName': 'MP Room  4 ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-23T09:12:25.95',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2896,
#   'TotalCapacity': 75,
#   'LocationName': 'MP Room 5',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T06:40:17.41',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2897,
#   'TotalCapacity': 588,
#   'LocationName': 'MP Room 6 ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T06:40:18.093',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2904,
#   'TotalCapacity': 342,
#   'LocationName': 'MP Room 7',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2023-09-22T07:14:36.91',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 423,
#   'FacilityName': 'ARC',
#   'IsClosed': False},
#  {'LocationId': 2880,
#   'TotalCapacity': 400,
#   'LocationName': 'ODC  North Turf Fields ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2020-07-23T15:20:53.383',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 581,
#   'FacilityName': 'Outdoor Center Play Fields',
#   'IsClosed': True},
#  {'LocationId': 2881,
#   'TotalCapacity': 400,
#   'LocationName': 'ODC South Turf Fields ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2020-07-23T15:20:53.647',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 581,
#   'FacilityName': 'Outdoor Center Play Fields',
#   'IsClosed': True},
#  {'LocationId': 2882,
#   'TotalCapacity': 60,
#   'LocationName': 'ODC North Basketball Courts ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2020-07-23T15:20:53.897',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 581,
#   'FacilityName': 'Outdoor Center Play Fields',
#   'IsClosed': True},
#  {'LocationId': 2883,
#   'TotalCapacity': 60,
#   'LocationName': 'ODC South Basketball Courts',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2020-07-23T15:20:54.147',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 581,
#   'FacilityName': 'Outdoor Center Play Fields',
#   'IsClosed': True},
#  {'LocationId': 2884,
#   'TotalCapacity': 120,
#   'LocationName': 'ODC Sand Volleyball Courts',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2020-07-23T15:20:54.397',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 581,
#   'FacilityName': 'Outdoor Center Play Fields',
#   'IsClosed': True},
#  {'LocationId': 2885,
#   'TotalCapacity': 60,
#   'LocationName': 'ODC Tennis Courts ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2020-07-23T15:20:54.633',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 581,
#   'FacilityName': 'Outdoor Center Play Fields',
#   'IsClosed': True},
#  {'LocationId': 2887,
#   'TotalCapacity': 400,
#   'LocationName': 'Complex Softball Fields ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2020-09-21T12:13:31.613',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 582,
#   'FacilityName': 'Complex Fields',
#   'IsClosed': False},
#  {'LocationId': 2888,
#   'TotalCapacity': 700,
#   'LocationName': 'Complex Grass Fields ',
#   'CountOfParticipants': 0,
#   'PercetageCapacity': 0,
#   'LastUpdatedDateAndTime': '2020-09-21T12:13:31.037',
#   'LastCount': 0,
#   'MinColor': '#ffc90e',
#   'MidColor': None,
#   'MaxColor': '#ed1c24',
#   'MinCapacityRange': 60,
#   'MaxCapacityRange': 90,
#   'CountCapacityColorEnabled': True,
#   'FacilityId': 582,
#   'FacilityName': 'Complex Fields',
#   'IsClosed': False}]
